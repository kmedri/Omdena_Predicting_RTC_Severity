# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so

# %%
acc = pd.read_parquet("DATA/parquet/vehicle_data.parquet")
# sns.pairplot(df1)

# %%
veh = pd.read_parquet("DATA/parquet/accident_data.parquet")
# sns.pairplot(df2)

# %%
acc.shape
# Out:
# (2177205, 24)

# %%
acc.ndim
# Out:
# 2

# %%
pd.set_option('display.max_columns', None) #For showing all columns
acc.head()
# Out:
#   Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0  200401BS00001            26 - 35             3.0
# 1  200401BS00002            26 - 35             NaN
# 2  200401BS00003            26 - 35             4.0
# 3  200401BS00003            66 - 75             NaN
# 4  200401BS00004            26 - 35             1.0
#
#           Driver_Home_Area_Type  Driver_IMD_Decile  Engine_Capacity_.CC.  \
# 0                    Urban area                4.0                1588.0
# 1                    Urban area                3.0                   NaN
# 2  Data missing or out of range                NaN                 998.0
# 3  Data missing or out of range                NaN                   NaN
# 4                    Urban area                4.0                 124.0
#
#   Hit_Object_in_Carriageway Hit_Object_off_Carriageway  \
# 0                      None                       None
# 1                      None                       None
# ...

# %%
acc.tail(7)
# Out:
#         Accident_Index            Age_Band_of_Driver  Age_of_Vehicle  \
# 2177198  2016984130916                       46 - 55             8.0
# 2177199  2016984130916  Data missing or out of range            11.0
# 2177200  2016984131116                       21 - 25            14.0
# 2177201  2016984131116                       56 - 65             NaN
# 2177202  2016984131216                       56 - 65             NaN
# 2177203  2016984131316                       16 - 20            13.0
# 2177204  2016984133416                       46 - 55             5.0
#
#                 Driver_Home_Area_Type  Driver_IMD_Decile  \
# 2177198                         Rural                NaN
# 2177199  Data missing or out of range                NaN
# 2177200                    Urban area                NaN
# 2177201                    Small town                NaN
# 2177202                    Urban area                3.0
# 2177203                    Urban area                6.0
# ...

# %%
round(acc.describe(), 2)
# Out:
#        Age_of_Vehicle  Driver_IMD_Decile  Engine_Capacity_.CC.  \
# count      1819056.00         1442393.00            1911344.00
# mean             7.11               5.39               2042.23
# std              4.73               2.82               1950.14
# min              1.00               1.00                  1.00
# 25%              3.00               3.00               1299.00
# 50%              7.00               5.00               1598.00
# 75%             10.00               8.00               1997.00
# max            111.00              10.00              96000.00
#
#        Vehicle_Location.Restricted_Lane  Vehicle_Reference        Year
# count                        2175888.00         2177205.00  2177205.00
# mean                               0.11               1.55     2010.93
# std                                0.88               0.78        3.69
# min                                0.00               1.00     2004.00
# ...

# %%
datatypes = acc.dtypes
print(datatypes)
# Out:
# Accident_Index                       object
# Age_Band_of_Driver                   object
# Age_of_Vehicle                      float64
# Driver_Home_Area_Type                object
# Driver_IMD_Decile                   float64
# Engine_Capacity_.CC.                float64
# Hit_Object_in_Carriageway            object
# Hit_Object_off_Carriageway           object
# Journey_Purpose_of_Driver            object
# Junction_Location                    object
# make                                 object
# model                                object
# Propulsion_Code                      object
# Sex_of_Driver                        object
# Skidding_and_Overturning             object
# Towing_and_Articulation              object
# Vehicle_Leaving_Carriageway          object
# Vehicle_Location.Restricted_Lane    float64
# Vehicle_Manoeuvre                    object
# Vehicle_Reference                     int64
# Vehicle_Type                         object
# ...

# %%
acc.isnull().sum()
# Out:
# Accident_Index                           0
# Age_Band_of_Driver                       0
# Age_of_Vehicle                      358149
# Driver_Home_Area_Type                    0
# Driver_IMD_Decile                   734812
# Engine_Capacity_.CC.                265861
# Hit_Object_in_Carriageway                0
# Hit_Object_off_Carriageway               0
# Journey_Purpose_of_Driver                0
# Junction_Location                        0
# make                                110845
# model                               325331
# Propulsion_Code                     245843
# Sex_of_Driver                            0
# Skidding_and_Overturning                 0
# Towing_and_Articulation                  0
# Vehicle_Leaving_Carriageway              0
# Vehicle_Location.Restricted_Lane      1317
# Vehicle_Manoeuvre                        0
# Vehicle_Reference                        0
# Vehicle_Type                             0
# Was_Vehicle_Left_Hand_Drive              0
# ...

# %%
(acc.isnull().sum() / df1.shape[0]) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 (acc.isnull().sum() / df1.shape[0]) * 100
#
# NameError: name 'df1' is not defined

# %%
# unique values in column "Team"
print(acc['Driver_IMD_Decile'].unique())
# check the return type
print(type(acc['Driver_IMD_Decile'].unique()))
# Out:
# [ 4.  3. nan  8.  6. 10.  7.  5.  2.  1.  9.]
# <class 'numpy.ndarray'>

# %%
veh.shape
# Out:
# (1048575, 34)

# %%
veh.head(7)
# Out:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 0  200501BS00001              A           3218.0           None
# 1  200501BS00002              B            450.0              C
# 2  200501BS00003              C              0.0           None
# 3  200501BS00004              A           3220.0           None
# 4  200501BS00005           None              0.0           None
# 5  200501BS00006           None              0.0           None
# 6  200501BS00007              C              0.0   Unclassified
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 0              0.0           Serious                None  04/01/2005
# 1              0.0            Slight                None  05/01/2005
# 2              0.0            Slight                None  06/01/2005
# 3              0.0            Slight                None  07/01/2005
# 4              0.0            Slight                None  10/01/2005
# ...

# %%
veh.tail(7)
# Out:
#         Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 1048568  201091NM01085              A              9.0              B
# 1048569  201091NM01190              A             96.0   Unclassified
# 1048570  201091NM01760              A             95.0           None
# 1048571  201091NM01881              A             95.0           None
# 1048572  201091NM01935              A             96.0   Unclassified
# 1048573  201091NM01964              A              9.0   Unclassified
# 1048574  201091NM02142           None              0.0   Unclassified
#
#          2nd_Road_Number Accident_Severity   Carriageway_Hazards        Date  \
# 1048568           9152.0           Serious                  None  29/01/2010
# 1048569              0.0            Slight                  None  02/02/2010
# 1048570              0.0            Slight                  None  18/02/2010
# 1048571              0.0            Slight                  None  21/02/2010
# ...

# %%
round(veh.describe(), 2)
# Out:
#        1st_Road_Number  2nd_Road_Number  \
# count       1048573.00       1037772.00
# mean           1012.00           387.00
# std            1832.04          1316.67
# min               0.00             0.00
# 25%               0.00             0.00
# 50%             125.00             0.00
# 75%             706.00             0.00
# max            9999.00          9999.00
#
#        Did_Police_Officer_Attend_Scene_of_Accident    Latitude  \
# count                                   1048306.00  1048464.00
# mean                                          1.20       52.57
# std                                           0.41        1.42
# min                                           1.00       49.91
# 25%                                           1.00       51.49
# 50%                                           1.00       52.34
# 75%                                           1.00       53.46
# max                                           3.00       60.76
#
# ...

# %%
datatypes = veh.dtypes
print(datatypes)
# Out:
# Accident_Index                                  object
# 1st_Road_Class                                  object
# 1st_Road_Number                                float64
# 2nd_Road_Class                                  object
# 2nd_Road_Number                                float64
# Accident_Severity                               object
# Carriageway_Hazards                             object
# Date                                            object
# Day_of_Week                                     object
# Did_Police_Officer_Attend_Scene_of_Accident    float64
# Junction_Control                                object
# Junction_Detail                                 object
# Latitude                                       float64
# Light_Conditions                                object
# Local_Authority_(District)                      object
# Local_Authority_(Highway)                       object
# Location_Easting_OSGR                          float64
# ...

# %%
veh.isnull().sum()
# Out:
# Accident_Index                                      0
# 1st_Road_Class                                 305589
# 1st_Road_Number                                     2
# 2nd_Road_Class                                 439824
# 2nd_Road_Number                                 10803
# Accident_Severity                                   0
# Carriageway_Hazards                                29
# Date                                                0
# Day_of_Week                                         0
# Did_Police_Officer_Attend_Scene_of_Accident       269
# Junction_Control                                    0
# Junction_Detail                                     0
# Latitude                                          111
# Light_Conditions                                 2084
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# Location_Easting_OSGR                             111
# ...

# %%
(veh.isnull().sum() / veh.shape[0]) * 100
# Out:
# Accident_Index                                  0.000000
# 1st_Road_Class                                 29.143266
# 1st_Road_Number                                 0.000191
# 2nd_Road_Class                                 41.944925
# 2nd_Road_Number                                 1.030255
# Accident_Severity                               0.000000
# Carriageway_Hazards                             0.002766
# Date                                            0.000000
# Day_of_Week                                     0.000000
# Did_Police_Officer_Attend_Scene_of_Accident     0.025654
# Junction_Control                                0.000000
# Junction_Detail                                 0.000000
# Latitude                                        0.010586
# Light_Conditions                                0.198746
# Local_Authority_(District)                      0.000000
# Local_Authority_(Highway)                       0.000000
# ...

# %%
print(veh['1st_Road_Class'].value_counts(dropna=False))
print(sum(df2['1st_Road_Class'].value_counts(dropna=False)))
# Out:
# A           470854
# None        305589
# B           133179
# C            93983
# Motorway     42297
# A(M)          2673
# Name: 1st_Road_Class, dtype: int64
# 1048575

# %%
print(veh['2nd_Road_Class'].value_counts(dropna=False))
print(sum(veh['2nd_Road_Class'].value_counts(dropna=False)))
# Out:
# None            439824
# Unclassified    411064
# A               102148
# C                47542
# B                40221
# Motorway          6980
# A(M)               796
# Name: 2nd_Road_Class, dtype: int64
# 1048575

# %%
# Box plot
#
sns.boxplot(acc.Age_of_Vehicle)
#
# Distribution plot
#
sns.displot(acc.Age_of_Vehicle)

# %%
old_cars = acc.loc[(acc['Age_of_Vehicle'] < 22)]
old_cars.head()
# Out:
#   Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0  200401BS00001            26 - 35             3.0
# 2  200401BS00003            26 - 35             4.0
# 4  200401BS00004            26 - 35             1.0
# 5  200401BS00004            36 - 45            10.0
# 8  200401BS00012            46 - 55             3.0
#
#           Driver_Home_Area_Type  Driver_IMD_Decile  Engine_Capacity_.CC.  \
# 0                    Urban area                4.0                1588.0
# 2  Data missing or out of range                NaN                 998.0
# 4                    Urban area                4.0                 124.0
# 5  Data missing or out of range                NaN                1781.0
# 8  Data missing or out of range                NaN                2685.0
#
#   Hit_Object_in_Carriageway Hit_Object_off_Carriageway  \
# 0                      None                       None
# 2                      None                       None
# ...

# %%
acc['Age_of_Vehicle'] = acc['Age_of_Vehicle'].fillna(acc['Age_of_Vehicle'].mode()[0])

# %%
# Box plot
#
sns.boxplot(old_cars.Age_of_Vehicle)
#
# Distribution plot
#
sns.displot(old_cars.Age_of_Vehicle)

# %%
plt.figure(figsize=(50, 10))
sns.barplot(x='Age_of_Vehicle', y='Driver_IMD_Decile', data=old_cars)
# Out:
# <AxesSubplot: xlabel='Age_of_Vehicle', ylabel='Driver_IMD_Decile'>

# %%
acc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177205 entries, 0 to 2177204
# Data columns (total 24 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Accident_Index                    object
#  1   Age_Band_of_Driver                object
#  2   Age_of_Vehicle                    float64
#  3   Driver_Home_Area_Type             object
#  4   Driver_IMD_Decile                 float64
#  5   Engine_Capacity_.CC.              float64
#  6   Hit_Object_in_Carriageway         object
#  7   Hit_Object_off_Carriageway        object
#  8   Journey_Purpose_of_Driver         object
#  9   Junction_Location                 object
#  10  make                              object
#  11  model                             object
#  12  Propulsion_Code                   object
#  13  Sex_of_Driver                     object
#  14  Skidding_and_Overturning          object
#  15  Towing_and_Articulation           object
# ...

# %%
print(len(acc['Accident_Index']))
print(sum(acc['Accident_Index'].value_counts(dropna=False)))
print(len(veh['Accident_Index']))
print(sum(veh['Accident_Index'].value_counts(dropna=False)))
# Out:
# 2177205
# 2177205
# 1048575
# 1048575

# %%
print(acc['Year'].value_counts(dropna=False))
# Out:
# 2015    257845
# 2016    252500
# 2014    182353
# 2009    182321
# 2011    180616
# 2010    180367
# 2012    173859
# 2013    171625
# 2007    127172
# 2008    122445
# 2004    118797
# 2006    115017
# 2005    112288
# Name: Year, dtype: int64

# %%
print(acc['Year'].value_counts(dropna=False))
# Out:
# 2005    198735
# 2006    189161
# 2007    182115
# 2008    170591
# 2009    163554
# 2010    144419
# Name: Year, dtype: int64

# %%
print(veh['Accident_Index'].value_counts(dropna=False))
print(sum(veh['Accident_Index'].value_counts(dropna=False)))
# Out:
# 2.00513E+12      7277
# 2.00613E+12      7162
# 2.00713E+12      6867
# 2.00813E+12      6501
# 2.00913E+12      6255
#                  ...
# 200643W022056       1
# 200643W022076       1
# 200643W022106       1
# 200643W023036       1
# 201091NM02142       1
# Name: Accident_Index, Length: 671340, dtype: int64
# 1048575

# %%
print(acc['Accident_Index'].value_counts(dropna=False))
print(sum(acc['Accident_Index'].value_counts(dropna=False)))
# Out:
# 2013460234852    53
# 201543P296025    37
# 2011160B00431    24
# 2009559D05333    22
# 201522D501706    16
#                  ..
# 2009130400909     1
# 2009130400509     1
# 2009130400309     1
# 2009130400209     1
# 2016984133416     1
# Name: Accident_Index, Length: 1488981, dtype: int64
# 2177205

# %%
sample = veh.sample(len(veh))
fig, ax = plt.subplots(figsize=(70, 30))
sns.histplot((sample["Police_Force"]), ax=ax)
plt.savefig('police_force.pdf')

# %%
# sample1 = acc.sample(len(acc))
# fig, ax = plt.subplots(figsize=(90, 3))
# sns.histplot(('make'[sample1]), ax=ax)
# plt.savefig('make.pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 3
#       1 sample1 = df1.sample(len(df1))
#       2 fig, ax = plt.subplots(figsize=(90, 3))
# ----> 3 sns.histplot(('make'[sample1]), ax=ax)
#       4 plt.savefig('make.pdf')
#
# TypeError: string indices must be integers

# %%
ndf = df1['Age_of_Vehicle']

# %%
ndf.isnull().sum()
# Out:
# 358149

# %%
print(ndf.shape)
# Out:
# (2177205,)

# %%
print(ndf)
# Out:
# 0           3.0
# 1           NaN
# 2           4.0
# 3           NaN
# 4           1.0
#            ...
# 2177200    14.0
# 2177201     NaN
# 2177202     NaN
# 2177203    13.0
# 2177204     5.0
# Name: Age_of_Vehicle, Length: 2177205, dtype: float64

# %%
sns.displot(ndf, height=4, aspect=3, color='green', kde=True)

# %%
ndf_mean = round(ndf.fillna(ndf.mean()), 0)
sns.displot(ndf_mean, height=4, aspect=3, color='green', kde=True)

# %%
ndf_mean.isnull().sum()
# Out:
# 0

# %%
print(ndf_mean)
# Out:
# 0           3.0
# 1           7.0
# 2           4.0
# 3           7.0
# 4           1.0
#            ...
# 2177200    14.0
# 2177201     7.0
# 2177202     7.0
# 2177203    13.0
# 2177204     5.0
# Name: Age_of_Vehicle, Length: 2177205, dtype: float64

# %%
ndf_median = round(ndf.fillna(ndf.median()), 0)
sns.displot(ndf_median, height=4, aspect=3, color='green', kde=True)

# %%
ndf_median.isnull().sum()
# Out:
# 0

# %%
ndf_mode = ndf.fillna(ndf.mode()[0])
sns.displot(ndf_mode, height=4, aspect=3, color='green', kde=True)

# %%
ndf_mode.isnull().sum()
# Out:
# 0

# %%
print(ndf_mode)
# Out:
# 0           3.0
# 1           NaN
# 2           4.0
# 3           NaN
# 4           1.0
#            ...
# 2177200    14.0
# 2177201     NaN
# 2177202     NaN
# 2177203    13.0
# 2177204     5.0
# Name: Age_of_Vehicle, Length: 2177205, dtype: float64

# %%
abroads = veh[['1st_Road_Class', '1st_Road_Number', '2nd_Road_Class', '2nd_Road_Number', 'Latitude', 'Longitude']]
print(abroads[:30])
# Out:
#    1st_Road_Class  1st_Road_Number 2nd_Road_Class  2nd_Road_Number   Latitude  \
# 0               A           3218.0           None              0.0  51.489096
# 1               B            450.0              C              0.0  51.520075
# 2               C              0.0           None              0.0  51.525301
# 3               A           3220.0           None              0.0  51.482442
# 4            None              0.0           None              0.0  51.495752
# 5            None              0.0           None              0.0  51.515540
# 6               C              0.0   Unclassified              0.0  51.512695
# 7               A            315.0           None              0.0  51.502260
# 8               A           3212.0              B            304.0  51.483420
# 9               B            450.0              C              0.0  51.512443
# 10              A              4.0              B            325.0  51.494902
# ...
